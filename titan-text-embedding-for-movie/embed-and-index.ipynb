# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth, helpers
import boto3
from botocore.config import Config
import json
from dotenv import load_dotenv
import os

load_dotenv()

boto_config = Config(
    region_name = 'us-west-2',
    signature_version = 'v4',
    retries = {
        'max_attempts': 10,
        'mode': 'standard'
    }
)

session = boto3.Session(profile_name=os.environ.get('profile'))

client = session.client("opensearchserverless", config=boto_config)
 
host = "uhyhuh4pzdqdx2goan62.us-west-2.aoss.amazonaws.com"
region = "us-west-2"
service = "aoss"
credentials = session.get_credentials()
auth = AWSV4SignerAuth(credentials, region, service)
 
client = OpenSearch(
    hosts = [{"host": host, "port": 443}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection,
    pool_maxsize = 20
)
 
index_name = "oscars-index"
index_body = {
    "mappings": {
        "properties": {
            "nominee_text": {"type": "text"},
            "nominee_vector": {
                "type": "knn_vector",
                "dimension": 1536,
                "method": {
                    "engine": "nmslib",
                    "space_type": "cosinesimil",
                    "name": "hnsw",
                    "parameters": {"ef_construction": 512, "m": 16},
                },
            },
        }
    },
    "settings": {
        "index": {
            "number_of_shards": 2,
            "knn.algo_param": {"ef_search": 512},
            "knn": True,
        }
    },
}
 
try:
    # response = client.indices.delete(index_name)
    # print(json.dumps(response, indent=2))
    response = client.indices.create(index_name, body=index_body)
    print(json.dumps(response, indent=2))
except Exception as ex:
    print(ex)
# Out:
# {
#   "acknowledged": true
# }
# {
#   "acknowledged": true,
#   "shards_acknowledged": true,
#   "index": "oscars-index"
# }

# %%
import pandas as pd
df=pd.read_csv('./data/oscars.csv')
df.head()
df=df.loc[df['year_ceremony'] == 2023]
df=df.dropna(subset=['film'])
df['category'] = df['category'].str.lower()
df.head()
df['text'] = df['name'] + ' got nominated under the category, ' + df['category'] + ', for the film ' + df['film'] + ' to win the award'
df.loc[df['winner'] == False, 'text'] = df['name'] + ' got nominated under the category, ' + df['category'] + ', for the film ' + df['film'] + ' but did not win'
df.head()['text']
# Out:
# 10639    Austin Butler got nominated under the category...
# 10640    Colin Farrell got nominated under the category...
# 10641    Brendan Fraser got nominated under the categor...
# 10642    Paul Mescal got nominated under the category, ...
# 10643    Bill Nighy got nominated under the category, a...
# Name: text, dtype: object

# %%
bedrock = session.client('bedrock-runtime')

def text_embedding(text):
    body=json.dumps({"inputText": text})
    response = bedrock.invoke_model(body=body, modelId='amazon.titan-embed-text-v1', accept='application/json', contentType='application/json')
    response_body = json.loads(response.get('body').read())
    embedding = response_body.get('embedding')
    return embedding
df=df.assign(embedding=(df["text"].apply(lambda x : text_embedding(x))))

# %%
# bedrock_static = session.client('bedrock')
# response = bedrock_static.list_foundation_models(
#     byOutputModality='EMBEDDING'
# )
# print(response)
# Out:
# {'ResponseMetadata': {'RequestId': 'e39d8e71-0e39-4eb8-9543-04f9ab182d1a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 12 Jan 2024 11:55:37 GMT', 'content-type': 'application/json', 'content-length': '2806', 'connection': 'keep-alive', 'x-amzn-requestid': 'e39d8e71-0e39-4eb8-9543-04f9ab182d1a'}, 'RetryAttempts': 0}, 'modelSummaries': [{'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-embed-g1-text-02', 'modelId': 'amazon.titan-embed-g1-text-02', 'modelName': 'Titan Text Embeddings v2', 'providerName': 'Amazon', 'inputModalities': ['TEXT'], 'outputModalities': ['EMBEDDING'], 'customizationsSupported': [], 'inferenceTypesSupported': ['ON_DEMAND'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-embed-text-v1:2:8k', 'modelId': 'amazon.titan-embed-text-v1:2:8k', 'modelName': 'Titan Embeddings G1 - Text', 'providerName': 'Amazon', 'inputModalities': ['TEXT'], 'outputModalities': ['EMBEDDING'], 'responseStreamingSupported': False, 'customizationsSupported': [], 'inferenceTypesSupported': ['PROVISIONED'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-embed-text-v1', 'modelId': 'amazon.titan-embed-text-v1', 'modelName': 'Titan Embeddings G1 - Text', 'providerName': 'Amazon', 'inputModalities': ['TEXT'], 'outputModalities': ['EMBEDDING'], 'responseStreamingSupported': False, 'customizationsSupported': [], 'inferenceTypesSupported': ['ON_DEMAND'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-embed-image-v1:0', 'modelId': 'amazon.titan-embed-image-v1:0', 'modelName': 'Titan Multimodal Embeddings G1', 'providerName': 'Amazon', 'inputModalities': ['TEXT', 'IMAGE'], 'outputModalities': ['EMBEDDING'], 'customizationsSupported': ['FINE_TUNING'], 'inferenceTypesSupported': ['ON_DEMAND', 'PROVISIONED'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-embed-image-v1', 'modelId': 'amazon.titan-embed-image-v1', 'modelName': 'Titan Multimodal Embeddings G1', 'providerName': 'Amazon', 'inputModalities': ['TEXT', 'IMAGE'], 'outputModalities': ['EMBEDDING'], 'customizationsSupported': [], 'inferenceTypesSupported': ['ON_DEMAND'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/cohere.embed-english-v3', 'modelId': 'cohere.embed-english-v3', 'modelName': 'Embed English', 'providerName': 'Cohere', 'inputModalities': ['TEXT'], 'outputModalities': ['EMBEDDING'], 'responseStreamingSupported': False, 'customizationsSupported': [], 'inferenceTypesSupported': ['ON_DEMAND'], 'modelLifecycle': {'status': 'ACTIVE'}}, {'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/cohere.embed-multilingual-v3', 'modelId': 'cohere.embed-multilingual-v3', 'modelName': 'Embed Multilingual', 'providerName': 'Cohere', 'inputModalities': ['TEXT'], 'outputModalities': ['EMBEDDING'], 'responseStreamingSupported': False, 'customizationsSupported': [], 'inferenceTypesSupported': ['ON_DEMAND'], 'modelLifecycle': {'status': 'ACTIVE'}}]}

# %%
# df.head()
# Out:
#        year_film  year_ceremony  ceremony                 category  \
# 10639       2022           2023        95  actor in a leading role
# 10640       2022           2023        95  actor in a leading role
# 10641       2022           2023        95  actor in a leading role
# 10642       2022           2023        95  actor in a leading role
# 10643       2022           2023        95  actor in a leading role
#
#                  name                       film  winner  \
# 10639   Austin Butler                      Elvis   False
# 10640   Colin Farrell  The Banshees of Inisherin   False
# 10641  Brendan Fraser                  The Whale    True
# 10642     Paul Mescal                   Aftersun   False
# 10643      Bill Nighy                     Living   False
#
#                                                     text  \
# 10639  Austin Butler got nominated under the category...
# 10640  Colin Farrell got nominated under the category...
# 10641  Brendan Fraser got nominated under the categor...
# 10642  Paul Mescal got nominated under the category, ...
# 10643  Bill Nighy got nominated under the category, a...
#
#                                                embedding
# 10639  [-0.109375, -0.16601562, 0.25390625, -0.621093...
# 10640  [-0.46484375, -0.055664062, 0.23828125, -0.761...
# 10641  [0.26757812, -0.56640625, 0.22265625, -0.40429...
# 10642  [-0.43359375, 0.032714844, 0.28125, -0.5390625...
# 10643  [-0.43554688, -0.21289062, 0.18359375, -0.4335...

# %%
def add_document(vector,text):
    document = {
      "nominee_vector": vector,
      "nominee_text": text
    }
    # print(document)
    response = client.index(
        index = 'oscars-index',
        body = document,
        timeout = 60
    )
    print('\nAdding document:')
    print(response) 
df.apply(lambda row: add_document(row['embedding'], row['text']), axis=1)
# Out:
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AH3GV_YwBrUVuMHll6s3G', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AILmV_YwBuHU76EbX7dUK', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AIHGV_YwBrUVuMHll7s3a', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AIbmV_YwBuHU76EbX8NWl', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AIXGV_YwBrUVuMHll8s2t', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AIrmV_YwBuHU76EbX9NVx', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AInGV_YwBrUVuMHll9s0V', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AI7mV_YwBuHU76EbX99XZ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AI3GV_YwBrUVuMHll-s0K', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJLmV_YwBuHU76EbX-9W7', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJHGV_YwBrUVuMHll_c1h', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJbmV_YwBuHU76EbX_9U8', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJXGW_YwBrUVuMHllAc0-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJrmW_YwBuHU76EbXAtXm', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJnGW_YwBrUVuMHllBM2q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJ7mW_YwBuHU76EbXBtXb', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AJ3GW_YwBrUVuMHllCM2P', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKLmW_YwBuHU76EbXCtUq', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKHGW_YwBrUVuMHllDM0X', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKbmW_YwBuHU76EbXDdXy', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKXGW_YwBrUVuMHllD82R', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKrmW_YwBuHU76EbXEdVO', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AKnGW_YwBrUVuMHllEs3z', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AK7mW_YwBuHU76EbXFNW2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AK3GW_YwBrUVuMHllFs1s', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALLmW_YwBuHU76EbXGNUk', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALHGW_YwBrUVuMHllGc3P', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALbmW_YwBuHU76EbXG9WE', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALXGW_YwBrUVuMHllHc0m', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALrmW_YwBuHU76EbXH9U2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ALnGW_YwBrUVuMHllIc06', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AL7mW_YwBuHU76EbXI9Uy', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AL3GW_YwBrUVuMHllJM3P', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMLmW_YwBuHU76EbXJtWJ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMHGW_YwBrUVuMHllKM0w', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMbmW_YwBuHU76EbXKdXN', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMXGW_YwBrUVuMHllK813', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMrmW_YwBuHU76EbXLdVR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AMnGW_YwBrUVuMHllLs3-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AM7mW_YwBuHU76EbXMNWc', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AM3GW_YwBrUVuMHllMs1D', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANLmW_YwBuHU76EbXNNUV', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANHGW_YwBrUVuMHllNc3h', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANbmW_YwBuHU76EbXN9W_', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANXGW_YwBrUVuMHllOc16', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANrmW_YwBuHU76EbXO9Uc', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ANnGW_YwBrUVuMHllPM3C', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AN7mW_YwBuHU76EbXPtWN', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AN3GW_YwBrUVuMHllQM1t', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AOLmW_YwBuHU76EbXQtUJ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AOHGW_YwBrUVuMHllQ82i', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AObmW_YwBuHU76EbXRdU9', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AOXGW_YwBrUVuMHllRs33', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AOrmW_YwBuHU76EbXSNWS', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AOnGW_YwBrUVuMHllSs1i', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AO7mW_YwBuHU76EbXTNUm', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AO3GW_YwBrUVuMHllTs0E', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APLmW_YwBuHU76EbXT9Ws', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APHGW_YwBrUVuMHllUc1K', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APbmW_YwBuHU76EbXUtXn', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APXGW_YwBrUVuMHllVM2Q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APrmW_YwBuHU76EbXVtU7', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3APnGW_YwBrUVuMHllV83e', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AP7mW_YwBuHU76EbXWdWO', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AP3GW_YwBrUVuMHllW81h', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQLmW_YwBuHU76EbXXNX_', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQHGW_YwBrUVuMHllXs3G', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQbmW_YwBuHU76EbXYNWR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQXGW_YwBrUVuMHllYs17', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQrmW_YwBuHU76EbXZNV0', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQnGW_YwBrUVuMHllZs1q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQ7mW_YwBuHU76EbXaNUS', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AQ3GW_YwBrUVuMHllac3c', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARLmW_YwBuHU76EbXa9Wu', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARHGW_YwBrUVuMHllbc1N', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARbmW_YwBuHU76EbXb9Ui', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARXGW_YwBrUVuMHllcM3E', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARrmW_YwBuHU76EbXctV4', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ARnGW_YwBrUVuMHlldM0O', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AR7mW_YwBuHU76EbXddXp', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AR3GW_YwBrUVuMHlleM0G', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASLmW_YwBuHU76EbXedXd', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASHGW_YwBrUVuMHlle812', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASbmW_YwBuHU76EbXfdUl', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASXGW_YwBrUVuMHllfs37', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASrmW_YwBuHU76EbXgNWR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ASnGW_YwBrUVuMHllgs1J', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AS7mW_YwBuHU76EbXg9Xr', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AS3GW_YwBrUVuMHllhc2a', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATLmW_YwBuHU76EbXh9Vj', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATHGW_YwBrUVuMHlliM3-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATbmW_YwBuHU76EbXitXV', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATXGW_YwBrUVuMHlljM2p', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATrmW_YwBuHU76EbXjtVD', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ATnGW_YwBrUVuMHllj839', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AT7mW_YwBuHU76EbXktUG', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AT3GW_YwBrUVuMHllk83N', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AULmW_YwBuHU76EbXldWc', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AUHGW_YwBrUVuMHlll81w', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AUbmW_YwBuHU76EbXmdUs', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AUXGW_YwBrUVuMHllms3q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AUrmW_YwBuHU76EbXnNWK', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AUnGW_YwBrUVuMHllns1Q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AU7mW_YwBuHU76EbXoNUE', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AU3GW_YwBrUVuMHlloc2U', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVLmW_YwBuHU76EbXo9Wb', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVHGW_YwBrUVuMHllpc1L', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVbmW_YwBuHU76EbXptX2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVXGW_YwBrUVuMHllqM2q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVrmW_YwBuHU76EbXqtW-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AVnGW_YwBrUVuMHllrM1i', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AV7mW_YwBuHU76EbXrtVI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AV3GW_YwBrUVuMHllr83f', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWLmW_YwBuHU76EbXsdV-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWHGW_YwBrUVuMHlls82E', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWbmW_YwBuHU76EbXtdUW', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWXGW_YwBrUVuMHllts3I', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWrmW_YwBuHU76EbXuNVm', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AWnGW_YwBrUVuMHllus0W', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AW7mW_YwBuHU76EbXu9W1', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AW3GW_YwBrUVuMHllvc2M', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
# 10639    None
# 10640    None
# 10641    None
# 10642    None
# 10643    None
#          ...
# 10755    None
# 10756    None
# 10757    None
# 10758    None
# 10764    None
# Length: 121, dtype: object

# %%
def search_index(vector):
    document = {
        "size": 15,
        "_source": {"excludes": ["nominee_vector"]},
        "query": {
            "knn": {
                 "nominee_vector": {
                     "vector": vector,
                     "k":15
                 }
            }
        }
    }
    response = client.search(
        body = document,
        index = "oscars-index",
        timeout = 60
    )
    return response

query='who won the award for best music?'
vector=text_embedding(query)

response=search_index(vector)
response['hits']['hits']
# Out:
# [{'_index': 'oscars-index',
#   '_id': '1%3A0%3AQLmW_YwBuHU76EbXXNX_',
#   '_score': 0.7270102,
#   '_source': {'nominee_text': 'Volker Bertelmann got nominated under the category, music (original score), for the film All Quiet on the Western Front to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQHGW_YwBrUVuMHllXs3G',
#   '_score': 0.7232194,
#   '_source': {'nominee_text': 'Justin Hurwitz got nominated under the category, music (original score), for the film Babylon but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ARLmW_YwBuHU76EbXa9Wu',
#   '_score': 0.7190479,
#   '_source': {'nominee_text': 'Music by M.M. Keeravaani; Lyric by Chandrabose got nominated under the category, music (original song), for the film RRR to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQ3GW_YwBrUVuMHllac3c',
#   '_score': 0.7148727,
#   '_source': {'nominee_text': 'Music by Tems, Rihanna, Ryan Coogler and Ludwig Goransson; Lyric by Tems and Ryan Coogler got nominated under the category, music (original song), for the film Black Panther: Wakanda Forever but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQnGW_YwBrUVuMHllZs1q',
#   '_score': 0.71246034,
#   '_source': {'nominee_text': 'Music and Lyric by Diane Warren got nominated under the category, music (original song), for the film Tell It like a Woman but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQXGW_YwBrUVuMHllYs17',
#   '_score': 0.70840085,
#   '_source': {'nominee_text': 'Son Lux got nominated under the category, music (original score), for the film Everything Everywhere All at Once but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQ7mW_YwBuHU76EbXaNUS',
#   '_score': 0.7004877,
#   '_source': {'nominee_text': 'Music and Lyric by Lady Gaga and BloodPop got nominated under the category, music (original song), for the film Top Gun: Maverick but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ARHGW_YwBrUVuMHllbc1N',
#   '_score': 0.6990064,
#   '_source': {'nominee_text': 'Music by Ryan Lott, David Byrne and Mitski; Lyric by Ryan Lott and David Byrne got nominated under the category, music (original song), for the film Everything Everywhere All at Once but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AU3GW_YwBrUVuMHlloc2U',
#   '_score': 0.6849683,
#   '_source': {'nominee_text': 'Mark Weingarten, James H. Mather, Al Nelson, Chris Burdon and Mark Taylor got nominated under the category, sound, for the film Top Gun: Maverick to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AUXGW_YwBrUVuMHllms3q',
#   '_score': 0.67821705,
#   '_source': {'nominee_text': 'Viktor Prášil, Frank Kruse, Markus Stemler, Lars Ginzel and Stefan Korte got nominated under the category, sound, for the film All Quiet on the Western Front but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQbmW_YwBuHU76EbXYNWR',
#   '_score': 0.6764615,
#   '_source': {'nominee_text': 'Carter Burwell got nominated under the category, music (original score), for the film The Banshees of Inisherin but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AMXGW_YwBrUVuMHllK813',
#   '_score': 0.6725197,
#   '_source': {'nominee_text': 'Daniel Kwan and Daniel Scheinert got nominated under the category, directing, for the film Everything Everywhere All at Once to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AQrmW_YwBuHU76EbXZNV0',
#   '_score': 0.6689026,
#   '_source': {'nominee_text': 'John Williams got nominated under the category, music (original score), for the film The Fabelmans but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AUrmW_YwBuHU76EbXnNWK',
#   '_score': 0.666888,
#   '_source': {'nominee_text': 'Julian Howarth, Gwendolyn Yates Whittle, Dick Bernstein, Christopher Boyes, Gary Summers and Michael Hedges got nominated under the category, sound, for the film Avatar: The Way of Water but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AOXGW_YwBrUVuMHllRs33',
#   '_score': 0.6621672,
#   '_source': {'nominee_text': 'Paul Rogers got nominated under the category, film editing, for the film Everything Everywhere All at Once to win the award'}}]

# %%
query='which film has its name related to animals?'
vector=text_embedding(query)

response=search_index(vector)
response['hits']['hits']
# Out:
# [{'_index': 'oscars-index',
#   '_id': '1%3A0%3AK7mW_YwBuHU76EbXFNW2',
#   '_score': 0.6087976,
#   '_source': {'nominee_text': 'Chris Williams and Jed Schlanger got nominated under the category, animated feature film, for the film The Sea Beast but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AKrmW_YwBuHU76EbXEdVO',
#   '_score': 0.5999809,
#   '_source': {'nominee_text': 'Dean Fleischer Camp, Elisabeth Holm, Andrew Goldman, Caroline Kaplan and Paul Mezey got nominated under the category, animated feature film, for the film Marcel the Shell with Shoes On but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AKnGW_YwBrUVuMHllEs3z',
#   '_score': 0.5870316,
#   '_source': {'nominee_text': 'Joel Crawford and Mark Swift got nominated under the category, animated feature film, for the film Puss in Boots: The Last Wish but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ATHGW_YwBrUVuMHlliM3-',
#   '_score': 0.5794037,
#   '_source': {'nominee_text': 'Charlie Mackesy and Matthew Freud got nominated under the category, short film (animated), for the film The Boy, the Mole, the Fox and the Horse to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ATnGW_YwBrUVuMHllj839',
#   '_score': 0.57732046,
#   '_source': {'nominee_text': 'Lachlan Pendragon got nominated under the category, short film (animated), for the film An Ostrich Told Me the World Is Fake and I Think I Believe It but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ATbmW_YwBuHU76EbXitXV',
#   '_score': 0.577242,
#   '_source': {'nominee_text': 'Amanda Forbis and Wendy Tilby got nominated under the category, short film (animated), for the film The Flying Sailor but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AWrmW_YwBuHU76EbXuNVm',
#   '_score': 0.57368577,
#   '_source': {'nominee_text': 'Written by Steven Spielberg & Tony Kushner got nominated under the category, writing (original screenplay), for the film The Fabelmans but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AMrmW_YwBuHU76EbXLdVR',
#   '_score': 0.57128924,
#   '_source': {'nominee_text': 'Steven Spielberg got nominated under the category, directing, for the film The Fabelmans but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ANrmW_YwBuHU76EbXO9Uc',
#   '_score': 0.57111347,
#   '_source': {'nominee_text': 'Kartiki Gonsalves and Guneet Monga got nominated under the category, documentary short film, for the film The Elephant Whisperers to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AKXGW_YwBrUVuMHllD82R',
#   '_score': 0.56812865,
#   '_source': {'nominee_text': "Guillermo del Toro, Mark Gustafson, Gary Ungar and Alex Bulkley got nominated under the category, animated feature film, for the film Guillermo del Toro's Pinocchio to win the award"}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AK3GW_YwBrUVuMHllFs1s',
#   '_score': 0.5658392,
#   '_source': {'nominee_text': 'Domee Shi and Lindsey Collins got nominated under the category, animated feature film, for the film Turning Red but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AULmW_YwBuHU76EbXldWc',
#   '_score': 0.5657269,
#   '_source': {'nominee_text': 'Alice Rohrwacher and Alfonso Cuarón got nominated under the category, short film (live action), for the film Le Pupille but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AVLmW_YwBuHU76EbXo9Wb',
#   '_score': 0.56528324,
#   '_source': {'nominee_text': 'Frank Petzold, Viktor Müller, Markus Frank and Kamil Jafar got nominated under the category, visual effects, for the film All Quiet on the Western Front but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AV3GW_YwBrUVuMHllr83f',
#   '_score': 0.5640856,
#   '_source': {'nominee_text': 'Written by Kazuo Ishiguro got nominated under the category, writing (adapted screenplay), for the film Living but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3ATrmW_YwBuHU76EbXjtVD',
#   '_score': 0.56393117,
#   '_source': {'nominee_text': 'Sara Gunnarsdóttir and Pamela Ribon got nominated under the category, short film (animated), for the film My Year of Dicks but did not win'}}]
