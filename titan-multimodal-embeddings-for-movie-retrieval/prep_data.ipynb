# %%
import os
import json
import pandas as pd
import urllib.request
import boto3
import base64
import requests

from requests.auth import HTTPBasicAuth
from botocore.config import Config

# %%
json_files = [pos_json for pos_json in os.listdir('movielens/') if pos_json.endswith('.json')]
json_data = []
for index, js in enumerate(json_files):
    with open(os.path.join('movielens/', js)) as json_file:
        json_text = json.load(json_file).get('data').get('searchResults')
        json_data.extend(json_text)

# %%
df = pd.DataFrame([json_data[i]['movie'] for i in range(len(json_data))])

# %%
def download_image(url, file_path, file_name):
    full_path = file_path + file_name
    urllib.request.urlretrieve(url, full_path)

# %%
for index, row in df.iterrows():
    url = 'https://image.tmdb.org/t/p/w500/' + row['posterPath']
    download_image(url, 'images/', row['posterPath'])

# %%
from dotenv import load_dotenv
load_dotenv()

boto_config = Config(
    region_name = 'us-west-2',
    signature_version = 'v4',
    retries = {
        'max_attempts': 10,
        'mode': 'standard'
    }
)

session = boto3.Session(profile_name=os.environ.get('profile'))

bedrock = session.client("bedrock", config=boto_config)
bedrock_runtime = session.client("bedrock-runtime", config=boto_config)

# %%
def get_embedding_for_poster(image_path):
    with open(image_path, "rb") as image_file:
        input_image = base64.b64encode(image_file.read()).decode('utf8')

    body = json.dumps(
        {
            "inputImage": input_image
        }
    )

    response = bedrock_runtime.invoke_model(
        body=body, 
        modelId="amazon.titan-embed-image-v1", 
        accept="application/json", 
        contentType="application/json"       
    )

    vector_json = json.loads(response['body'].read().decode('utf8'))
    image_name = image_path.split("/")[-1].split(".")[0]

    return vector_json, image_name

def get_embedding_for_poster_and_title(image_path, title):
    with open(image_path, "rb") as image_file:
        input_image = base64.b64encode(image_file.read()).decode('utf8')

    body = json.dumps(
        {
            "inputImage": input_image,
            "inputText": title
        }
    )

    response = bedrock_runtime.invoke_model(
        body=body, 
        modelId="amazon.titan-embed-image-v1", 
        accept="application/json", 
        contentType="application/json"       
    )

    vector_json = json.loads(response['body'].read().decode('utf8'))
    image_name = image_path.split("/")[-1].split(".")[0]

    return vector_json, image_name


def get_embedding_for_text(text):
    body = json.dumps(
        {
            "inputText": text
        }
    )

    response = bedrock_runtime.invoke_model(
        body=body, 
        modelId="amazon.titan-embed-image-v1", 
        accept="application/json", 
        contentType="application/json"       
    )

    vector_json = json.loads(response['body'].read().decode('utf8'))

    return vector_json, text

# %%
for index, row in df.iterrows():
    image_path = 'images/' + row['posterPath']
    vector_json, image_name = get_embedding_for_poster(image_path)
    with open('embeddings/' + image_name + '.json', 'w') as f:
        json.dump(vector_json, f)

# %%
for index, row in df.iterrows():
    image_path = 'images/' + row['posterPath']
    vector_json, image_name = get_embedding_for_poster_and_title(image_path, row['title'])
    with open('embeddings/' + 'with_title_' + image_name + '.json', 'w') as f:
        json.dump(vector_json, f)

# %%
df = df.drop(columns=['dvdReleaseDate', 'backdropPaths', 'youtubeTrailerIds', 'numRatings', 'avgRating'])

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth, helpers

session = boto3.Session(profile_name=os.environ.get('profile'))

client = session.client("opensearchserverless", config=boto_config)
 
host = "uhyhuh4pzdqdx2goan62.us-west-2.aoss.amazonaws.com"
region = "us-west-2"
service = "aoss"
credentials = session.get_credentials()
auth = AWSV4SignerAuth(credentials, region, service)
 
client = OpenSearch(
    hosts = [{"host": host, "port": 443}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection,
    pool_maxsize = 20
)
 
index_name = "multi-modal-embedding-index"

# %%
index_body = {
    "mappings": {
        "properties": {
            "titan_multimodal_embedding": {
                "type": "knn_vector",
                "dimension": 1024
            },
            "title": { 
                "type": "text"            
            },
            "plotSummary": { 
                "type": "text"            
            },
            "movieId": { 
                "type": "keyword"            
            },
            "imdbMovieId": { 
                "type": "keyword"            
            },
            "posterPath": { 
                "type": "text"            
            },
        }
    },
    "settings": {
        "index": {
            "number_of_shards": 2,
            "knn.algo_param": {"ef_search": 512},
            "knn": True,
        }
    },
}
 
try:
    # response = client.indices.delete(index_name)
    # print(json.dumps(response, indent=2))
    response = client.indices.create(index_name, body=index_body)
    print(json.dumps(response, indent=2))
except Exception as ex:
    print(ex)
# Out:
# {
#   "acknowledged": true,
#   "shards_acknowledged": true,
#   "index": "multi-modal-embedding-index"
# }

# %%
def create_document_from_row(row):

    embedding_file = 'embeddings/with_title_' + row['posterPath'].split("/")[-1].split(".")[0] + '.json'
    with open(embedding_file) as json_file:
        data = json.load(json_file)

    document = {
        "titan_multimodal_embedding": data['embedding'],
        "title": row['title'],
        "plotSummary": row['plotSummary'],
        "movieId": row['movieId'],
        "imdbMovieId": row['imdbMovieId'],
        "posterPath": row['posterPath']        
    }
    return document

# %%
for index, row in df.iterrows():
    document = create_document_from_row(row)
    response = client.index(
        index = index_name,
        body = document,
        timeout = 60
    )
    print('\nAdding document:')
    print(response)
# Out:
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AeHGqAY0BrUVuMHllvs1b', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AeLmqAY0BuHU76EbXwNU4', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AeXGqAY0BrUVuMHllws0C', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AebmqAY0BuHU76EbXw9Wi', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AenGqAY0BrUVuMHllxc1E', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AermqAY0BuHU76EbXx9U9', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ae3GqAY0BrUVuMHllyM3O', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ae7mqAY0BuHU76EbXytVa', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfHGqAY0BrUVuMHlly83l', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfLmqAY0BuHU76EbXzdWF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfXGqAY0BrUVuMHllz80S', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfbmqAY0BuHU76EbX0NWn', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfnGqAY0BrUVuMHll0s1M', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AfrmqAY0BuHU76EbX09Xr', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Af3GqAY0BrUVuMHll1c2B', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Af7mqAY0BuHU76EbX19UJ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgHGqAY0BrUVuMHll2M2N', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgLmqAY0BuHU76EbX2tWz', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgXGqAY0BrUVuMHll3M1c', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgbmqAY0BuHU76EbX3dXm', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgnGqAY0BrUVuMHll382M', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AgrmqAY0BuHU76EbX4dUb', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ag3GqAY0BrUVuMHll4s2h', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ag7mqAY0BuHU76EbX5NV4', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhHGqAY0BrUVuMHll5s0G', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhLmqAY0BuHU76EbX59W3', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhXGqAY0BrUVuMHll6c1R', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhbmqAY0BuHU76EbX69VT', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhnGqAY0BrUVuMHll7M3q', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AhrmqAY0BuHU76EbX7tWP', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ah3GqAY0BrUVuMHll8M1R', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ah7mqAY0BuHU76EbX8dXj', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AiHGqAY0BrUVuMHll8816', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AiLmqAY0BuHU76EbX9dUP', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AiXGqAY0BrUVuMHll9s2b', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AibmqAY0BuHU76EbX-NVR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AinGqAY0BrUVuMHll-c3n', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AirmqAY0BuHU76EbX-9Wr', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ai3GqAY0BrUVuMHll_c1M', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ai7mqAY0BuHU76EbX_tX4', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjHGrAY0BrUVuMHllAM2c', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjLmrAY0BuHU76EbXAtUg', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjXGrAY0BrUVuMHllA83V', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjbmrAY0BuHU76EbXBdW2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjnGrAY0BrUVuMHllB81S', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AjrmrAY0BuHU76EbXCNXl', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Aj3GrAY0BrUVuMHllCs2W', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Aj7mrAY0BuHU76EbXDNUf', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AkHGrAY0BrUVuMHllDc26', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AkLmrAY0BuHU76EbXD9Vx', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AkXGrAY0BrUVuMHllEc0h', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AkbmrAY0BuHU76EbXEtWr', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AknGrAY0BrUVuMHllFM00', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3AkrmrAY0BuHU76EbXFdW7', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ak3GrAY0BrUVuMHllF816', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'multi-modal-embedding-index', '_id': '1%3A0%3Ak7mrAY0BuHU76EbXGdUK', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}

# %%
def get_embedding_for_text(text):
    body = json.dumps(
        {
            "inputText": text
        }
    )

    response = bedrock_runtime.invoke_model(
        body=body, 
        modelId="amazon.titan-embed-image-v1", 
        accept="application/json", 
        contentType="application/json"       
    )

    vector_json = json.loads(response['body'].read().decode('utf8'))

    return vector_json, text

# %%
def query(text, n=5):

    text_embedding = get_embedding_for_text(text)

    query = {
        "size": n,
        "query": {
            "knn": {
            "titan_multimodal_embedding": {
                "vector": text_embedding[0]['embedding'],
                "k": n
            }
            }
        },
        "_source": ["movieId", "title", "imdbMovieId", "posterPath", "plotSummary"]
        }

    response = client.search(
        body = query,
        index = index_name,
        timeout = 60
    )
    return response

# %%
query_str='Nuclear physicist'
response=query(query_str)

response['hits']['hits']
# Out:
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 0, 'successful': 0, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 5, 'relation': 'eq'},
#   'max_score': 0.5717137,
#   'hits': [{'_index': 'multi-modal-embedding-index',
#     '_id': '1%3A0%3AjnGrAY0BrUVuMHllB81S',
#     '_score': 0.5717137,
#     '_source': {'imdbMovieId': '15398776',
#      'plotSummary': "The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.",
#      'movieId': 287699,
#      'title': 'Oppenheimer',
#      'posterPath': '/8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg'}},
#    {'_index': 'multi-modal-embedding-index',
#     '_id': '1%3A0%3Ae3GqAY0BrUVuMHllyM3O',
#     '_score': 0.5489049,
#     '_source': {'imdbMovieId': '5884796',
#      'plotSummary': 'After a heroic job of successfully landing his storm-damaged aircraft in a war zone, a fearless pilot finds himself between the agendas of multiple militias planning to take the plane and its passengers hostage.',
#      'movieId': 282671,
#      'title': 'Plane',
#      'posterPath': '/qi9r5xBgcc9KTxlOLjssEbDgO0J.jpg'}},
#    {'_index': 'multi-modal-embedding-index',
#     '_id': '1%3A0%3Ah7mqAY0BuHU76EbX8dXj',
#     '_score': 0.5458131,
#     '_source': {'imdbMovieId': '21867434',
#      'plotSummary': "Two mismatched entrepreneurs – egghead innovator Mike Lazaridis and cut-throat businessman Jim Balsillie – joined forces in an endeavour that was to become a worldwide hit in little more than a decade. The story of the meteoric rise and catastrophic demise of the world's first smartphone.",
#      'movieId': 286777,
#      'title': 'BlackBerry',
#      'posterPath': '/neV35lK7em4rIY9QIoH1cruErPA.jpg'}},
#    {'_index': 'multi-modal-embedding-index',
#     '_id': '1%3A0%3AknGrAY0BrUVuMHllFM00',
#     '_score': 0.54517955,
#     '_source': {'imdbMovieId': '0439572',
#      'plotSummary': "When his attempt to save his family inadvertently alters the future, Barry Allen becomes trapped in a reality in which General Zod has returned and there are no Super Heroes to turn to. In order to save the world that he is in and return to the future that he knows, Barry's only hope is to race for his life. But will making the ultimate sacrifice be enough to reset the universe?",
#      'movieId': 286901,
#      'title': 'The Flash',
#      'posterPath': '/rktDFPbfHfUbArZ6OOOKsXcv0Bm.jpg'}},
#    {'_index': 'multi-modal-embedding-index',
#     '_id': '1%3A0%3AhLmqAY0BuHU76EbX59W3',
#     '_score': 0.54499716,
#     '_source': {'imdbMovieId': '12758060',
#      'plotSummary': 'In 1988, American video game salesman Henk Rogers discovers the video game Tetris. When he sets out to bring the game to the world, he enters a dangerous web of lies and corruption behind the Iron Curtain.',
#      'movieId': 284291,
#      'title': 'Tetris',
#      'posterPath': '/4F2QwCOYHJJjecSvdOjStuVLkpu.jpg'}}]}}
